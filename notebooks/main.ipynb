# %% [markdown]
# # Imports

# %%
# Imports
import xarray as xr
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Definitions

# %%
# Longitude is represented from 0.0 - 359.0 in the files
# To convert them from -180 - 180 to 0 - 360:
def convert_lon(lon: float) -> float:
    """
    Converts longitudes from -180 to 180 degree range format to 0 to 360 degree 
    range.

    Parameters:
        lon (float): The longitude in the -180 to 180 degree format.
    
    Returns:
        converted_longitude (float): The equivalent longitude in the 0 to 360 
        degree format.
    """
    return float((lon + 360.0) % 360)

# %%
def parse_grads_ctl(ctl_file_path):
    """
    Parses a GrADS .ctl file to extract metadata for dimensions and variables from 
    the referenced .dat binary file.

    Parameters:
        ctl_file_path (str): The path to the GrADS .ctl file.

    Returns:
        metadata (dict): A dictionary containing parsed metadata like 'dset', 'undef',
              'title', 'xdef', 'ydef', 'tdef', 'zdef', 'num_vars', and 'variables'.
    """
    metadata = {}
    original_lines = []
    with open(ctl_file_path, 'r') as f:
        original_lines = f.readlines()

    lines_processed = [line.strip().lower() for line in original_lines]
    
    vars_start_index = -1

    for i, line_content in enumerate(lines_processed):
        if line_content.startswith("dset"):
            metadata["dset"] = original_lines[i].strip().split()[1].strip('^')
        elif line_content.startswith("undef"):
            metadata["undef"] = float(original_lines[i].strip().split()[1])
        elif line_content.startswith("title"):
            metadata["title"] = original_lines[i].strip().split(' ', 1)[1]
        elif line_content.startswith("options"):
            metadata["byte_order"] = line_content.split()[1]
        elif line_content.startswith("xdef"):
            parts = original_lines[i].strip().split()
            metadata["xdef"] = {"count": int(parts[1]), "type": parts[2], "start": float(parts[3]), "increment": float(parts[4])}
        elif line_content.startswith("ydef"):
            parts = original_lines[i].strip().split()
            metadata["ydef"] = {"count": int(parts[1]), "type": parts[2], "start": float(parts[3]), "increment": float(parts[4])}
        elif line_content.startswith("tdef"):
            parts = original_lines[i].strip().split()
            metadata["tdef"] = {"count": int(parts[1]), "type": parts[2], "start_str": parts[3], "increment_str": parts[4]}
        elif line_content.startswith("zdef"):
            parts = original_lines[i].strip().split()
            metadata["zdef"] = {"count": int(parts[1]), "type": parts[2], "start": float(parts[3]), "increment": float(parts[4])}
        elif line_content.startswith("vars"):
            metadata["num_vars"] = int(line_content.split()[1])
            metadata["variables"] = []
            vars_start_index = i

    if vars_start_index != -1:
        for j in range(vars_start_index + 1, len(original_lines)):
            sub_line = original_lines[j].strip()
            if sub_line.lower() == "endvars":
                break
            
            parts = sub_line.split()
            if parts:
                var_name = parts[0]
                description = ''
                if "**" in parts:
                    desc_start_idx = parts.index("**") + 1
                    description = " ".join(parts[desc_start_idx:])
                else:
                    if len(parts) > 2:
                        description = " ".join(parts[2:]) 
                
                metadata["variables"].append({"name": var_name, "description": description.strip()})
    
    return metadata

# %%
def subset(ds: xr.Dataset, left_lon: float, right_lon: float, up_lat: float, 
           down_lat: float) -> xr.Dataset:
    """
    Subsets an xarray Dataset containing georeferenced data to a given bound.

    Parameters:
        ds (xarray.Dataset): An xarray Dataset to be subset.
        left_lon (float): The western longitude bound.
        right_lon (float): The eastern longitude bound.
        up_lat (float): The northern latitude bound.
        down_lat (float): The southern latitude bound.
    
    Returns:
        subset_dataset (xarray.Dataset): A new xarray Dataset containing the subset 
        data within the latitude and longitude bounding box.
    """
    subset_ds = ds.sel(lat= slice(down_lat, up_lat), lon= slice(left_lon, right_lon))
    return subset_ds

# %% [markdown]
# If not interested in subsetting the data to a given region, comment out that line.

# %%
def convert_grads_to_netcdf(ctl_file_path: str, output_nc_file: str, 
                            left_lon: float = None, right_lon: float = None, 
                            up_lat: float = None, down_lat: float = None) -> None:
    """
    Converts a GrADS binary data file (.dat) associated with a .ctl file into a 
    NetCDF (.nc) file. Optional Parameters are for subsetting the xarray 
    Dataset.

    Parameters:
        ctl_file_path (str): The path to the GrADS .ctl control file.
        output_nc_file (str): The desired path for the output NetCDF file.
        left_lon (float): Optional. The western longitude bound.
        right_lon (float): Optional. The eastern longitude bound.
        up_lat (float): Optional. The northern latitude bound.
        down_lat (float): Optional. The southern latitude bound.
    """
    metadata = parse_grads_ctl(ctl_file_path)

    data_filename_from_ctl = metadata["dset"]
    data_file_dir = os.path.dirname(ctl_file_path)
    data_file_path = os.path.join(data_file_dir, data_filename_from_ctl)

    # 1. Infer spatial dimensions and coordinates
    x_coords = np.arange(metadata["xdef"]["start"],
                         metadata["xdef"]["start"] + metadata["xdef"]["count"] * metadata["xdef"]["increment"],
                         metadata["xdef"]["increment"])
    y_coords = np.arange(metadata["ydef"]["start"],
                         metadata["ydef"]["start"] + metadata["ydef"]["count"] * metadata["ydef"]["increment"],
                         metadata["ydef"]["increment"])
    z_coords = np.arange(metadata["zdef"]["start"],
                         metadata["zdef"]["start"] + metadata["zdef"]["count"] * metadata["zdef"]["increment"],
                         metadata["zdef"]["increment"])

    # 2. Time parsing: Convert GrADS time format to pandas DatetimeIndex
    try:
        start_date = pd.to_datetime(metadata["tdef"]["start_str"], format="%HZ%d%b%Y")
    except ValueError:
        print(f"Warning: Could not parse start date '{metadata["tdef"]["start_str"]}' with '%HZ%d%b%Y'. Attempting generic parse.")
        start_date = pd.to_datetime(metadata["tdef"]["start_str"]) 

    freq_map = {'1yr': 'YS', '1mo': 'MS', '1dy': 'D', '1hr': 'H', 
                '1mn': 'min', '1sc': 'S'}
    time_freq = metadata['tdef']['increment_str'].lower()
    if time_freq in freq_map:
        time_freq = freq_map[time_freq]
    else:
        print(f"Warning: Could not directly map GrADS time increment '{metadata['tdef']['increment_str']}' to pandas frequency. Trying simple replacement.")
        if 'yr' in time_freq: time_freq = time_freq.replace('yr', 'Y')
        elif 'mo' in time_freq: time_freq = time_freq.replace('mo', 'M')
        elif 'dy' in time_freq: time_freq = time_freq.replace('dy', 'D')
        elif 'hr' in time_freq: time_freq = time_freq.replace('hr', 'H')
        elif 'mn' in time_freq: time_freq = time_freq.replace('mn', 'min')
        elif 'sc' in time_freq: time_freq = time_freq.replace('sc', 'S')
        else:
            print(f"Error: Unable to determine pandas frequency from '{metadata['tdef']['increment_str']}'. Defaulting to 'D'. This may cause incorrect time coordinates.")
            time_freq = 'D'

    time_coords = pd.date_range(start=start_date, periods=metadata['tdef']['count'], freq=time_freq)

    # 3. Determine data type and byte order
    base_dtype = np.float32 
    endian = '<' if metadata.get('byte_order', 'little_endian').lower() == 'little_endian' else '>'
    data_dtype = np.dtype(f"{endian}f{base_dtype().itemsize}")

    # 4. Calculate total expected number of values (elements) from CTL
    total_expected_elements = (metadata['tdef']['count'] *
                               metadata['zdef']['count'] *
                               metadata['num_vars'] *
                               metadata['ydef']['count'] *
                               metadata['xdef']['count'])
    
    expected_data_bytes = total_expected_elements * base_dtype().itemsize

    try:
        actual_file_size_bytes = os.path.getsize(data_file_path)
        
        # Calculate potential header/footer bytes
        excess_bytes = actual_file_size_bytes - expected_data_bytes

        if excess_bytes < 0:
            raise ValueError(f"Error: Data file '{data_file_path}' is smaller than expected. "
                             f"Expected {expected_data_bytes} bytes but found {actual_file_size_bytes} bytes. Conversion aborted.")
        elif excess_bytes > 0:
            print(f"Warning: Data file '{data_file_path}' contains {excess_bytes} excess bytes.")
            print("Assuming these excess bytes are at the *beginning* of the file (a header) and will be skipped.")
            bytes_to_skip_at_start = excess_bytes
        else:
            bytes_to_skip_at_start = 0
            print(f"File size matches expected data size: {actual_file_size_bytes} bytes.")

        # Read the binary data: Open the file and skip potential header, then read data
        with open(data_file_path, 'rb') as f:
            if bytes_to_skip_at_start > 0:
                f.seek(bytes_to_skip_at_start)
                print(f"Skipped {bytes_to_skip_at_start} bytes at the beginning of the file.")
            
            raw_data = np.fromfile(f, dtype=data_dtype, count=total_expected_elements)

            # Verify that we actually read the expected number of elements
            if raw_data.size != total_expected_elements:
                 raise ValueError(f"Failed to read expected number of elements after skipping header. "
                                  f"Expected {total_expected_elements}, but read {raw_data.size}.")

        # Reshape the raw data.
        data_shape = (
            metadata['tdef']['count'],
            metadata['zdef']['count'],
            metadata['num_vars'], 
            metadata['ydef']['count'],
            metadata['xdef']['count']
        )
        # By trial and error, GrADS data is seen C-ordered (row-major)
        reshaped_data = raw_data.reshape(data_shape, order='C') 

        # 5. Create DataArrays for each variable and populate the Dataset
        data_vars = {}
        for i, var_info in enumerate(metadata['variables']):
            var_data_array = reshaped_data[:, :, i, :, :]
            # Missing data is changed to NaN for compatibility with Pandas and xarray
            var_data_array[var_data_array == metadata['undef']] = np.nan
            squeezed_data = var_data_array.squeeze()
            
            dims = []
            if metadata['tdef']['count'] > 1: dims.append('time')
            if metadata['zdef']['count'] > 1: dims.append('z')
            dims.append('lat')
            dims.append('lon')

            current_data_array_coords = {}
            if 'time' in dims:
                current_data_array_coords['time'] = time_coords
            if 'z' in dims:
                current_data_array_coords['z'] = z_coords
            current_data_array_coords['lat'] = y_coords
            current_data_array_coords['lon'] = x_coords

            data_vars[var_info['name']] = xr.DataArray(
                squeezed_data,
                coords=current_data_array_coords,
                dims=dims,
                name=var_info['name'],
                # USE to_open_netcdf.ipynb TO READ AND MANUALLY CHANGE VARIABLES
                attrs={'long_name': var_info['description'], 'units': 'kg/m^2/s'}
            )

        # 6. Create the xarray Dataset
        ds = xr.Dataset(
            data_vars=data_vars,
            coords={
                'time': time_coords,
                'z': z_coords,
                'lat': y_coords,
                'lon': x_coords
            },
            attrs={'title': metadata.get('title', 'Converted from GrADS binary')}
        )

        ############# OPTIONAL HELPER FOR SUBSETING ############
        # ds = subset(ds, left_lon, right_lon, up_lat, down_lat)
        ########################################################

        # Ensure the output directory exists
        output_dir = os.path.dirname(output_nc_file)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)

        # 7. Save to NetCDF
        ds.to_netcdf(output_nc_file)
        print(f"Successfully converted '{ctl_file_path}' to '{output_nc_file}'")

    except FileNotFoundError:
        print(f"Error: Data file '{data_file_path}' not found. Please ensure the .dat file exists and the `dset` path in your .ctl is correct relative to the .ctl file.")
    except Exception as e:
        print(f"An unexpected error occurred during conversion: {e}")
        import traceback
        traceback.print_exc()

# %%
def main(model_name, left_lon, right_lon, up_lat, down_lat):
    # input_dir = f"../precipitation/monthly/{model_name}/to_convert/"
    # output_dir = f"../precipitation/monthly/{model_name}/converted/"

    # input_dir = f"../precipitation/seasonal/{model_name}/to_convert/"
    # output_dir = f"../precipitation/seasonal/{model_name}/converted/"

    # input_dir = f"../2m_air_temperature/monthly/{model_name}/to_convert/"
    # output_dir = f"../2m_air_temperature/monthly/{model_name}/converted/"

    # input_dir = f"../2m_air_temperature/seasonal/{model_name}/to_convert/"
    # output_dir = f"../2m_air_temperature/seasonal/{model_name}/converted/"

    # input_dir = f"../sea_surface_temperature/monthly/{model_name}/to_convert/"
    # output_dir = f"../sea_surface_temperature/monthly/{model_name}/converted/"

    input_dir = f"../sea_surface_temperature/seasonal/{model_name}/to_convert/"
    output_dir = f"../sea_surface_temperature/seasonal/{model_name}/converted/"

    # Longitude is represented from 0.0 - 359.0
    left_lon = convert_lon(left_lon)
    right_lon = convert_lon(right_lon)
    
    try:
        for filename in os.listdir(input_dir):
            if filename.endswith(".ctl"):
                # Input file path
                ctl_file_path = os.path.join(input_dir, filename)

                # Output file path
                output_nc_filename = filename.replace(".ctl", ".nc")
                output_nc_file = os.path.join(output_dir, output_nc_filename)

                # Call
                convert_grads_to_netcdf(ctl_file_path, output_nc_file, left_lon, 
                                        right_lon, up_lat, down_lat)
    
    except FileNotFoundError:
        print(f"Directory: '{input_dir}' not found.")
    except Exception as e:
        print(f"Expection ocurred: {e}.")

    print(f"Iterated over '{input_dir}' directory.")

# %% [markdown]
# # To convert a single file

# %%
# The box is lon: -68 - -64, 
#            lat: 17.5 N - 19 N

# lat and lon values are float32 but the step is 1.0

left_lon = -68.0
right_lon = -64.0
# left_lon = -67.0
# right_lon = -65.0
up_lat = 19.0
down_lat = 17.0
# up_lat = 18.0
# down_lat = 18.0

input_dir = "../kumar_data/to_convert/"
output_dir = "../kumar_data/converted/"

# Longitude is represented from 0.0 - 359.0
left_lon = convert_lon(left_lon)
right_lon = convert_lon(right_lon)

print(left_lon, right_lon, up_lat, down_lat, input_dir, output_dir, sep="\n")

ctl_file_path = "../kumar_data/to_convert/obs_ts.ctl"
output_nc_file = "../kumar_data/converted/obs_ts.nc"
convert_grads_to_netcdf(ctl_file_path, output_nc_file, left_lon, right_lon, up_lat, down_lat)
# Out:
# 292.0
# 296.0
# 19.0
# 17.0
# ../kumar_data/to_convert/
# ../kumar_data/converted/
# Warning: Data file '../kumar_data/to_convert\obs_ts.dat' contains 15638400 excess bytes.
# Assuming these excess bytes are at the *beginning* of the file (a header) and will be skipped.
# Skipped 15638400 bytes at the beginning of the file.
# Successfully converted '../kumar_data/to_convert/obs_ts.ctl' to '../kumar_data/converted/obs_ts.nc'

# %% [markdown]
# # Main Call to Convert and Transform Data

# %%
# The box is lon: -68 - -64, 
#            lat: 17.5 N - 19 N

# lat and lon values are float32 but the step is 1.0

left_lon = -68.0
right_lon = -64.0
# left_lon = -67.0
# right_lon = -65.0
up_lat = 19.0
down_lat = 17.0
# up_lat = 18.0
# down_lat = 18.0

# Debugging print
# print(left_lon, right_lon, up_lat, down_lat, input_dir, output_dir, sep="\n")

# Available models are: "CanCM4i (CMC1)", "CCSM4", "CESM1", "CFSv2", "GEM-NEMO (CMC2)", "GEOS-5 (NASA)", "NMME"
for model_name in ["CanCM4i (CMC1)", "CCSM4", "CESM1", "CFSv2", "GEM-NEMO (CMC2)", "GEOS-5 (NASA)", "NMME"]:
    main(model_name, left_lon, right_lon, up_lat, down_lat)
# Out:
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/AprIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/AprIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/AugIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/AugIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/DecIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/DecIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/FebIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/FebIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/JanIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/JanIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/JulIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/JulIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/JunIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/JunIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/MarIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/MarIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/MayIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/MayIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/NovIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/NovIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/OctIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/OctIC_cmc1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/SepIC_cmc1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/converted/SepIC_cmc1_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/CanCM4i (CMC1)/to_convert/' directory.
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/AprIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/AprIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/AugIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/AugIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/DecIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/DecIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/FebIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/FebIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/JanIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/JanIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/JulIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/JulIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/JunIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/JunIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/MarIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/MarIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/MayIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/MayIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/NovIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/NovIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/OctIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/OctIC_ncar_ccsm4_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CCSM4/to_convert/SepIC_ncar_ccsm4_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CCSM4/converted/SepIC_ncar_ccsm4_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/CCSM4/to_convert/' directory.
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/AprIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/AprIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/AugIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/AugIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/DecIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/DecIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/FebIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/FebIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/JanIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/JanIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/JulIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/JulIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/JunIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/JunIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/MarIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/MarIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/MayIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/MayIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/NovIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/NovIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/OctIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/OctIC_ncar_cesm1_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CESM1/to_convert/SepIC_ncar_cesm1_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CESM1/converted/SepIC_ncar_cesm1_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/CESM1/to_convert/' directory.
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/AprIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/AprIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/AugIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/AugIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/DecIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/DecIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/FebIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/FebIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/JanIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/JanIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/JulIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/JulIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/JunIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/JunIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/MarIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/MarIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/MayIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/MayIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/NovIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/NovIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/OctIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/OctIC_cfsv2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/CFSv2/to_convert/SepIC_cfsv2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/CFSv2/converted/SepIC_cfsv2_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/CFSv2/to_convert/' directory.
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/AprIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/AprIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/AugIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/AugIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/DecIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/DecIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/FebIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/FebIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/JanIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/JanIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/JulIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/JulIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/JunIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/JunIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/MarIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/MarIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/MayIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/MayIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/NovIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/NovIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/OctIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/OctIC_cmc2_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/SepIC_cmc2_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/converted/SepIC_cmc2_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/GEM-NEMO (CMC2)/to_convert/' directory.
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/AprIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/AprIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/AugIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/AugIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/DecIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/DecIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/FebIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/FebIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/JanIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/JanIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/JulIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/JulIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/JunIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/JunIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/MarIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/MarIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/MayIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/MayIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/NovIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/NovIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/OctIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/OctIC_nasa_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/SepIC_nasa_sst_skill.ctl' to '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/converted/SepIC_nasa_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/GEOS-5 (NASA)/to_convert/' directory.
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/AprIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/AprIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/AugIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/AugIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/DecIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/DecIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/FebIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/FebIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/JanIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/JanIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/JulIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/JulIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/JunIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/JunIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/MarIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/MarIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/MayIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/MayIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/NovIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/NovIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/OctIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/OctIC_nmme_sst_skill.nc'
# File size matches expected data size: 1563840 bytes.
# Successfully converted '../sea_surface_temperature/seasonal/NMME/to_convert/SepIC_nmme_sst_skill.ctl' to '../sea_surface_temperature/seasonal/NMME/converted/SepIC_nmme_sst_skill.nc'
# Iterated over '../sea_surface_temperature/seasonal/NMME/to_convert/' directory.
